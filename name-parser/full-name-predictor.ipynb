# %%
def calc_accuracy():
    
    key_file_lines = open('dev-key.csv', 'r')
    output_file_lines = open('full-name-output.csv', 'r')
    
    answers = []
    keys = [] 
    boths = []
    
    for l in key_file_lines:
        [both , key] = l.strip().split(',')
        keys.append(key)
        boths.append(both)
        
    for l in output_file_lines:
        [_ , ans] = l.strip().split(',')
        answers.append(ans)
        
    correct = 0.0
    wrong = 0.0
    for a, k, b in zip(answers, keys, boths):
        if (a == k):
            correct +=1
        else:
            print(b)
            print(a)
            print(k)
            print('----')
            wrong +=1
    
    print(len(answers))
    print(len(keys))
    print(correct)
    print(wrong)
    print(wrong+correct)
    print('Accuracy ' + str((correct/len(keys)*1.0)*100.0) + ' %')
    
    key_file_lines.close()
    output_file_lines.close()

# %%
def load_dictionaries():
    
    female_firsts = []
    male_firsts = []
    last_names = []
    
    female_first_lines = open('dist.female.first.txt', 'r')
    male_first_lines = open('dist.male.first.txt', 'r')
    last_name_lines = open('Names_2010Census.csv', 'r')
    
    for l in female_first_lines:
        [first_name, _, _, _] = l.strip().split()
        female_firsts.append(first_name)
    
    for l in male_first_lines:
        [first_name, _, _, _] = l.strip().split()
        male_firsts.append(first_name)
        
    for l in last_name_lines:
        items = l.strip().split(',')
        last_name = items[0]
        last_names.append(last_name)
        
    return female_firsts, male_firsts, last_names

# %%
#minus the number of words between name1 and name2 60% accuracy
def predict_with_tokens_diff(name1, name2):
    
    first_person = name1.split()
    second_person = name2.split()
    
    keep = len(second_person) - len(first_person)
    
    if keep > 0:
        to_append = second_person[-keep:]
    elif keep == 0:
        to_append = []
    else:
        to_append = []
    
    prediction = first_person + to_append
    prediction = " ".join(prediction)

    return prediction

# %%
#minus the number of words between name1 and name2, and use only the last word in name2 70.8% accuracy
def predict_with_tokens_diff_last(name1, name2):
    
    first_person = name1.split()
    second_person = name2.split()
    
    keep = len(second_person) - len(first_person)
    
    if keep > 0:
        to_append = second_person[-1:]
    elif keep == 0:
        to_append = []
    else:
        to_append = []
    
    prediction = first_person + to_append
    prediction = " ".join(prediction)

    return prediction

# %%
#final rule-based method
def predict(name1, name2, female_firsts, male_firsts, last_names):
    
    to_append = []
    
    p1 = name1.split()
    p2 = name2.split()
    
    p1 = strip_titles(p1)
    p2 = strip_titles(p2)
    
    if len(p1) >= 3:
        return name1
    
    if len(p1) == 1:
        if len(p2) == 1:
            to_append = p2 
        if len(p2) == 2:
            to_append = p2[-1:]
        if len(p2) == 3:
            to_append = strip_first_names_forp2(p2)
            if len(to_append) == 0:
                to_append = p2[-1:]
        if len(p2) >= 4:
            to_append = p2[-2:]
    
    if len(p1) == 2:
        check = strip_first_names(p1)
        if len(check) != 0:
            if has_lastname(check):
                return name1
        if len(p2) == 1:
            to_append = p2  
        if len(p2) == 2:
            to_append = p2[-1:]
        if len(p2) == 3:
            to_append = strip_first_names_forp2(p2)
            if len(to_append) == 0:
                to_append = p2[-1:]
        if len(p2) >= 4:
            to_append = p2[-2:]

    prediction = name1 + " " + " ".join(to_append)

    return prediction

# %%
#check if all words are first names, first word is always firstname
def strip_first_names(name):
    new_name = []
    for w in name[1:]:
        if w in female_firsts or w in male_firsts:
            pass
        else:
            new_name.append(w)
    return new_name

# %%
#check if all words are first names, first word is always firstname
#last word is always last name
def strip_first_names_forp2(name):
    #sometimes the last word in a long name is a surname, but also a forename
    lastidx_name = name[-1]
    new_name = []
    for w in name[1:]:
        if w in female_firsts or w in male_firsts:
            if w == lastidx_name:
                new_name.append(w)
            else:
                pass
        else:
            new_name.append(w)
    return new_name

# %%
#strips any titles from a full name array and return the stripped array
def strip_titles(name):
    titles = ['COLONEL', 'MAJOR', 'REVEREND', 'DOCTOR', 'PROFESSOR']
    new_name = []
    for w in name:
        if w not in titles:
            new_name.append(w)
    return new_name

# %%
#check if the name has a last name
def has_lastname(name):
    for w in name:
        if w in last_names:
            return True
    return False

# %%
import sys

test_file = 'dev-test.csv'
output = open ('full-name-output.csv' , 'w')
test_lines = open(test_file , 'r')

female_firsts, male_firsts, last_names = load_dictionaries()

for line in test_lines:
    
    line = line.strip()
    [first_person , second_person] = line.split(' AND ')
    
    predicted_first_person = predict(first_person, second_person,
                                    female_firsts, male_firsts, last_names)
    output.write (line + ',' + predicted_first_person + '\n')
    
output.close

calc_accuracy()
# Out:
# LAURA STEVEN AND REVEREND ADELE KEITH
# LAURA STEVEN KEITH
# LAURA STEVEN
# ----
# LEE KUMAR AND NANCY NGUYEN
# LEE KUMAR
# LEE KUMAR NGUYEN
# ----
# JOSE LONEY AND MARIA TERRI LEHMAN
# JOSE LONEY
# JOSE LONEY LEHMAN
# ----
# MAHER AND TORRES CASTILLO MAPLE
# MAHER CASTILLO MAPLE
# MAHER MAPLE
# ----
# GISELE AND JENNIFER HEFFERNAN KANE
# GISELE HEFFERNAN KANE
# GISELE KANE
# ----
# ANTOINETTE TAVIS AND AL JASON CONDIT
# ANTOINETTE TAVIS
# ANTOINETTE TAVIS CONDIT
# ----
# JEANNE RUIZ AND DEXTER MASON MERCADO
# JEANNE RUIZ
# JEANNE RUIZ MERCADO
# ----
# SUNG BRENDA AND GERALD HUBRED STEADMAN
# SUNG BRENDA HUBRED STEADMAN
# SUNG BRENDA STEADMAN
# ----
# NIKKI GRAY AND KELLY RONALD GRILLO
# NIKKI GRAY
# NIKKI GRAY GRILLO
# ----
# IRENE GUYETTE AND ROSA LORENE GUAN
# IRENE GUYETTE
# IRENE GUYETTE GUAN
# ----
# PATRICIA BARRANCO AND NICK EDWARD GENTRY
# PATRICIA BARRANCO
# PATRICIA BARRANCO GENTRY
# ----
# ROBERT KENNETH AND JAMES PEREZ QUINN
# ROBERT KENNETH PEREZ QUINN
# ROBERT KENNETH QUINN
# ----
# LISA MOORE AND JOE CHEATUM
# LISA MOORE
# LISA MOORE CHEATUM
# ----
# VERONICA RAY AND DARRELL ROBERTO MARTIN
# VERONICA RAY MARTIN
# VERONICA RAY
# ----
# JEFF DWIGHT AND YVONNE FARMER MAYORGA
# JEFF DWIGHT FARMER MAYORGA
# JEFF DWIGHT MAYORGA
# ----
# GEIGER NGUYEN AND CARMEN BESSIE BRENDA
# GEIGER NGUYEN
# GEIGER NGUYEN BRENDA
# ----
# ALEXANDRA MARQUEZ AND COSME ALAN TU
# ALEXANDRA MARQUEZ
# ALEXANDRA MARQUEZ TU
# ----
# AMANDA ALVAREZ AND DOUGLAS HAROLD SIMON
# AMANDA ALVAREZ
# AMANDA ALVAREZ SIMON
# ----
# CHARLES HARRIS AND ANN LYONS
# CHARLES HARRIS LYONS
# CHARLES HARRIS
# ----
# KENDAL CHRISTINE AND DAMICO WILLIE ABDI
# KENDAL CHRISTINE ABDI
# KENDAL CHRISTINE WILLIE ABDI
# ----
# RUBY AND BARRINGER JOSEPH ADEBAYO
# RUBY ADEBAYO
# RUBY JOSEPH ADEBAYO
# ----
# DIANNE MITCHELL AND PHYLLIS PETERSON GRAHAM
# DIANNE MITCHELL PETERSON GRAHAM
# DIANNE MITCHELL
# ----
# JODY DENISE AND REVEREND LARRY BRYANT KLINE
# JODY DENISE KLINE
# JODY DENISE BRYANT KLINE
# ----
# MICHELE ANTONIA AND ARTHUR COPLIN VALENCIA
# MICHELE ANTONIA COPLIN VALENCIA
# MICHELE ANTONIA VALENCIA
# ----
# CHARLES DENIS AND JOHNNIE ANGELA HARRIS
# CHARLES DENIS HARRIS
# CHARLES DENIS
# ----
# SILER EDWARDS AND WILLIE KEITH BROOKS
# SILER EDWARDS
# SILER EDWARDS BROOKS
# ----
# BERGER INOCENCIA AND TIMOTHY KEPHART VANIER
# BERGER INOCENCIA KEPHART VANIER
# BERGER INOCENCIA VANIER
# ----
# SANDRA KAREN AND CHARLES LEONARD NAVARRO
# SANDRA KAREN NAVARRO
# SANDRA KAREN
# ----
# CALVIN SUAREZ AND DEBORAH PAULA ROPE DUGAS
# CALVIN SUAREZ
# CALVIN SUAREZ ROPE DUGAS
# ----
# TENA FRANCO AND DAVID RADEMACHER
# TENA FRANCO
# TENA FRANCO RADEMACHER
# ----
# ISRAEL FUENTES AND ELLEN EMA PAYNE
# ISRAEL FUENTES
# ISRAEL FUENTES PAYNE
# ----
# DARREN MARCOS AND HALL SIMMONS HEATH
# DARREN MARCOS SIMMONS HEATH
# DARREN MARCOS HEATH
# ----
# MARJORIE AND DENNIS BOLIVAR PRESCOTT
# MARJORIE BOLIVAR PRESCOTT
# MARJORIE PRESCOTT
# ----
# GRACE HEIDI AND HELEN DEJESUS OH
# GRACE HEIDI DEJESUS OH
# GRACE HEIDI OH
# ----
# CAROLE POPOWSKI AND PATRICK GERARD BRUNEAU
# CAROLE POPOWSKI
# CAROLE POPOWSKI BRUNEAU
# ----
# MARGARET AND JASON MOORHOUSE BIGGS
# MARGARET MOORHOUSE BIGGS
# MARGARET BIGGS
# ----
# VELMA HAPTONSTALL AND ROMEO FRED JONES YEO
# VELMA HAPTONSTALL
# VELMA HAPTONSTALL JONES YEO
# ----
# COURTNEY GARLAND AND MILDRED BONNIE CALVERT
# COURTNEY GARLAND CALVERT
# COURTNEY GARLAND
# ----
# DAVE AND ETHEL HIDALGO PYRON
# DAVE HIDALGO PYRON
# DAVE PYRON
# ----
# STEVEN WHITTAKER AND SIERRA FUJIOKA
# STEVEN WHITTAKER
# STEVEN WHITTAKER FUJIOKA
# ----
# LABRE JESSE AND ISABEL BUSTOS SLOAN
# LABRE JESSE BUSTOS SLOAN
# LABRE JESSE SLOAN
# ----
# PATRICIA WHITE AND ANDRES DEWEY DODD
# PATRICIA WHITE
# PATRICIA WHITE DODD
# ----
# ETHEL BROUILLETTE AND JOHN MICHAEL ROSS
# ETHEL BROUILLETTE
# ETHEL BROUILLETTE ROSS
# ----
# DANIEL FOSTER AND LORI TYLER SWARTZ
# DANIEL FOSTER SWARTZ
# DANIEL FOSTER
# ----
# THOMAS SCOVILL AND THOMAS RICK CONNIE
# THOMAS SCOVILL
# THOMAS SCOVILL CONNIE
# ----
# EARL AND BACK CARRION HOLBROOK
# EARL CARRION HOLBROOK
# EARL HOLBROOK
# ----
# JOYCE ENEDINA AND ROBERT STERLING BISHOP
# JOYCE ENEDINA BISHOP
# JOYCE ENEDINA STERLING BISHOP
# ----
# DEMARANVILLE JAMES AND SONIA SANDOVAL FAIRWEATHER
# DEMARANVILLE JAMES SANDOVAL FAIRWEATHER
# DEMARANVILLE JAMES FAIRWEATHER
# ----
# HOLLIS SHARP AND MARTIN DAVIS RUSSELL
# HOLLIS SHARP
# HOLLIS SHARP RUSSELL
# ----
# DAISY ANDERSON AND MICHAEL BLEVINS
# DAISY ANDERSON BLEVINS
# DAISY ANDERSON
# ----
# JONELL LAURIE AND WILLIAM BECKSTEIN MONTGOMERY
# JONELL LAURIE BECKSTEIN MONTGOMERY
# JONELL LAURIE MONTGOMERY
# ----
# DOUGLAS MAHAFFEY AND ANNIE VICTORIA CANADA
# DOUGLAS MAHAFFEY
# DOUGLAS MAHAFFEY CANADA
# ----
# KATHERINE MARY AND JASON POEL JOHNSON
# KATHERINE MARY POEL JOHNSON
# KATHERINE MARY JOHNSON
# ----
# RAY BONNICK AND JEANNE LESTER STEVE
# RAY BONNICK
# RAY BONNICK LESTER STEVE
# ----
# CRYSTAL ZOLLINGER AND SAMUEL GARRISON
# CRYSTAL ZOLLINGER
# CRYSTAL ZOLLINGER GARRISON
# ----
# HENTON AND DANIELLE JOANN BORJA
# HENTON BORJA
# HENTON JOANN BORJA
# ----
# BRANDON MURRAY AND VIRGINIA MARY GATLING
# BRANDON MURRAY GATLING
# BRANDON MURRAY
# ----
# MARYLEE RUTH AND ROBERT GENTRY POLAK
# MARYLEE RUTH GENTRY POLAK
# MARYLEE RUTH POLAK
# ----
# JOHN AND ROBINS KHAN CARBALLO
# JOHN KHAN CARBALLO
# JOHN CARBALLO
# ----
# CARRIE HOUSKA AND WILLIAM RICHARD PETIT
# CARRIE HOUSKA
# CARRIE HOUSKA PETIT
# ----
# DANIEL AND MADELINE ELL GARVIN
# DANIEL ELL GARVIN
# DANIEL GARVIN
# ----
# ROMERO AND GERALD MICHAEL CUNNINGHAM
# ROMERO CUNNINGHAM
# ROMERO MICHAEL CUNNINGHAM
# ----
# WASHINGTON JAMES AND GLENDA SUSAN FIGUEROA
# WASHINGTON JAMES FIGUEROA
# WASHINGTON JAMES
# ----
# CUNNINGHAM MARGARET AND ADAM WRIGHT DIMASCIO
# CUNNINGHAM MARGARET WRIGHT DIMASCIO
# CUNNINGHAM MARGARET DIMASCIO
# ----
# KYLE SHANE AND CARA JUSTICE DUDEK
# KYLE SHANE JUSTICE DUDEK
# KYLE SHANE DUDEK
# ----
# KENNETH RILEY AND JOSEPH MARTIN
# KENNETH RILEY MARTIN
# KENNETH RILEY
# ----
# CHRISTINE DAVIS AND THOMAS JERRY DEYOUNG
# CHRISTINE DAVIS DEYOUNG
# CHRISTINE DAVIS
# ----
# ALBERT MINCH AND LINDA PRINS
# ALBERT MINCH
# ALBERT MINCH PRINS
# ----
# SCOTT PAUL AND JOSHUA DEENA GAUTHIER
# SCOTT PAUL GAUTHIER
# SCOTT PAUL DEENA GAUTHIER
# ----
# LEWIS MIYAZAKI AND MCCOY GERALDINE TROYER
# LEWIS MIYAZAKI
# LEWIS MIYAZAKI TROYER
# ----
# ROBERT MANRIQUEZ AND VALERIE DELGADO
# ROBERT MANRIQUEZ
# ROBERT MANRIQUEZ DELGADO
# ----
# DONALD MIRANDA AND PEGGY STACY SELLERS
# DONALD MIRANDA SELLERS
# DONALD MIRANDA
# ----
# HECTOR TROY AND OSCAR MARLON BALTODANO
# HECTOR TROY BALTODANO
# HECTOR TROY
# ----
# GRANT COLEMAN AND BRENDA CORDOVA HOLLIDAY
# GRANT COLEMAN CORDOVA HOLLIDAY
# GRANT COLEMAN
# ----
# DOROTHY KINNEE AND EDWARD WALLER TORRES
# DOROTHY KINNEE
# DOROTHY KINNEE WALLER TORRES
# ----
# SANCHEZ BARRY AND MILDRED BRENDA SHETH
# SANCHEZ BARRY SHETH
# SANCHEZ BARRY
# ----
# AMANDA AND JESUS COOK RODRIGUEZ
# AMANDA COOK RODRIGUEZ
# AMANDA RODRIGUEZ
# ----
# VANDENBERG ROESENER AND BODIE DUDLEY
# VANDENBERG ROESENER
# VANDENBERG ROESENER DUDLEY
# ----
# SUSAN CHELSEY AND RICHARD HABERKERN
# SUSAN CHELSEY HABERKERN
# SUSAN CHELSEY
# ----
# JAMES DAVID AND JESSICA JAQUELINE MAZZIE
# JAMES DAVID MAZZIE
# JAMES DAVID
# ----
# STEPHEN SWANSON AND BEATRICE HAWKINS KETNER
# STEPHEN SWANSON
# STEPHEN SWANSON HAWKINS KETNER
# ----
# MARSHALL JOSE AND JACK DENNIS TURNER
# MARSHALL JOSE TURNER
# MARSHALL JOSE DENNIS TURNER
# ----
# CARLA VAUGHN AND NATHANIEL STEVEN SASHER
# CARLA VAUGHN SASHER
# CARLA VAUGHN
# ----
# TIMOTHY CHARLES AND FELICIA BEDNARCZYK
# TIMOTHY CHARLES BEDNARCZYK
# TIMOTHY CHARLES
# ----
# OSCAR ERIC AND CYNTHIA ELY SCHMIT
# OSCAR ERIC ELY SCHMIT
# OSCAR ERIC SCHMIT
# ----
# JARED HULBERT AND CONWAY SIU MILLER
# JARED HULBERT
# JARED HULBERT SIU MILLER
# ----
# KRISTIE CYNTHIA AND TOMMY GUDINO JAMES
# KRISTIE CYNTHIA GUDINO JAMES
# KRISTIE CYNTHIA JAMES
# ----
# KING AND RAY EASON HILL
# KING EASON HILL
# KING HILL
# ----
# JACK TYSON AND JOAN JOE SWEETSER
# JACK TYSON SWEETSER
# JACK TYSON
# ----
# RONALD MCGRAW AND KAREN LIBBY FLAMINI
# RONALD MCGRAW
# RONALD MCGRAW FLAMINI
# ----
# HAROLD JOSEPH AND CHRISTINE SCHIPANI SWAIM
# HAROLD JOSEPH SCHIPANI SWAIM
# HAROLD JOSEPH SWAIM
# ----
# LAWRENCE THOMAS AND PATRICIA LICKTEIG
# LAWRENCE THOMAS LICKTEIG
# LAWRENCE THOMAS
# ----
# BRENDA BARBER AND DARNELL GEORGE URIBE
# BRENDA BARBER
# BRENDA BARBER URIBE
# ----
# JOHN CHARLES AND OLLIE MUSTOE SAVE
# JOHN CHARLES MUSTOE SAVE
# JOHN CHARLES SAVE
# ----
# JOHN CALL AND JOAN STRENO
# JOHN CALL
# JOHN CALL STRENO
# ----
# TYRONE BRAY AND LUANN NIXON
# TYRONE BRAY
# TYRONE BRAY NIXON
# ----
# DORIS LYNCH AND NATHAN TRAVIS HILL
# DORIS LYNCH
# DORIS LYNCH HILL
# ----
# GEORGE GONDER AND ELVIRA KRYSTAL LESTER
# GEORGE GONDER
# GEORGE GONDER LESTER
# ----
# JOHNSTON FRASCA AND RUSSELL DENISE WILLIS
# JOHNSTON FRASCA
# JOHNSTON FRASCA WILLIS
# ----
# MENA KEVIN AND BRET ROBERT KRUEP
# MENA KEVIN KRUEP
# MENA KEVIN
# ----
# RONALD ELLIS AND SHEILA WELLING
# RONALD ELLIS WELLING
# RONALD ELLIS
# ----
# BOBBY SCHMITT AND ORTIZ CHERRY STAATS
# BOBBY SCHMITT
# BOBBY SCHMITT STAATS
# ----
# CHARLES SIKKEMA AND SHERRI MOORE
# CHARLES SIKKEMA
# CHARLES SIKKEMA MOORE
# ----
# 1000
# 1000
# 897.0
# 103.0
# 1000.0
# Accuracy 89.7 %
